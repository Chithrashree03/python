# %% [markdown]
# # File Handling

# %% [markdown]
# ### Write three lines about your favorite subject to a file named fav_subject.txt.
# ### Read and print each line from the file

# %%
with open(r"C:\chitts\fav_subject.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# My Favorite Subject
#
#         Mathematics is my favorite subject, because it as different branches like:
#     "Algebra, Geometry, Calculus, Statistics, Probability, Graph Theory" which feel
#     happy to solve this kind of problems and this helps to improve our knowledge.
